# %%
s = input("Enter some string: ")
i = 0
for x in s:
    print("positive index {} and negative index {} is: {}".format(i, i - len(s),x))
    i += 1

# %%
s = "Learning Python is very very easy!!!"

print(s[1:7:1])   # 'earnin'
print(s[1:7])     # 'earnin'
print(s[1:7:2])   # 'eri'
print(s[:7])      # 'Learnin'
print(s[7:])      # 'g Python is very very easy!!!'
print(s[::])      # 'Learning Python is very very easy!!!'
print(s[:])       # 'Learning Python is very very easy!!!'
print(s[::-1])    # '!!!ysae yrev yrev si nohtyP gninraeL'

# %%
s = 'deepleaningrocks'

print(s[1:6:2])      # 'epe'
print(s[::1])        # 'deepleaningrocks'
print(s[::-1])       # 'skcorgninaelpeed'
print(s[3:7:-1])     # ''   (empty — begin < end with negative step)
print(s[7:3:-1])     # 'ning'
print(s[0:10000:1])  # 'deepleaningrocks'  (out-of-range end is clipped)
print(s[-4:1:-1])    # 'orgninaelpe'
print(s[-4:1:-2])    # 'ogiae'
print(s[10000:2:-1]) # 'skcorgninaelp'
# s[9:0:0]           # ValueError: slice step cannot be zero
# Out:
# epe
# deepleaningrocks
# skcorgninaelpeed
#
# nael
# deepleaningrocks
# orgninaelpe
# ogiale
# skcorgninaelp

# %%
s[:-1]
# Out:
# 'deepleaningrock'

# %%
print("durga" + "soft")  # durgasoft
print("durga" * 3)       # durgadurgadurga
# Out:
# durgasoft
# durgadurgadurga

# %%
"info_"*4, "warning_"*5, "rohit_"*3
# Out:
# ('info_info_info_info_',
#  'warning_warning_warning_warning_warning_',
#  'rohit_rohit_rohit_')

# %%
s = 'durga'
print(len(s))  # 5
# Out:
# 5

# %%
len("every"), len("forward"), len("23456"), len("ture")
# Out:
# (5, 7, 5, 4)

# %%
s = "Learning Python is very easy!!!"
n = len(s)

print("Forward direction:")
i = 0
while i < n:
    print(s[i], end=' ')
    i += 1

print("\nBackward direction:")
i = -1
while i >= -n:
    print(s[i], end=' ')
    i -= 1
# Out:
# Forward direction:
# L e a r n i n g   P y t h o n   i s   v e r y   e a s y ! ! !
# Backward direction:
# ! ! ! y s a e   y r e v   s i   n o h t y P   g n i n r a e L

# %%
s = "Learning Python is very easy!!!"

print("Forward direction:")
for ch in s:
    print(ch, end=' ')

print("\nBackward direction:")
for ch in s[::-1]:
    print(ch, end=' ')
# Out:
# Forward direction:
# L e a r n i n g   P y t h o n   i s   v e r y   e a s y ! ! !
# Backward direction:
# ! ! ! y s a e   y r e v   s i   n o h t y P   g n i n r a e L

# %%
s = "Learning Python is very easy!!!"

# %%
print("Forward direction:")
[print(ch, end=' ') for ch in s]
# Out:
# Forward direction:
# L e a r n i n g   P y t h o n   i s   v e r y   e a s y ! ! !
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
print("\nBackward direction:")
[print(ch, end=' ') for ch in s[::-1]]
# Out:
# Backward direction:
# ! ! ! y s a e   y r e v   s i   n o h t y P   g n i n r a e L
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
s = "Learning Python is very easy!!!"

print("Forward direction:")
print(*s, sep=' ')

print("\nBackward direction:")
print(*s[::-1], sep=' ')
# Out:
# Forward direction:
# L e a r n i n g   P y t h o n   i s   v e r y   e a s y ! ! !
#
# Backward direction:
# ! ! ! y s a e   y r e v   s i   n o h t y P   g n i n r a e L
